# %% [markdown]
# ## Project Plan
# 1. Data Collection: Scrape Free courses data from the Analytics Vidhya website.
# 2. Data Preprocessing: Clean and preprocess the data for search functionalities.
# 3. Embedding Model: Use a pre-trained language model(BERT) to generate vector embeddings for course descriptions.
# 4. Search Tool Development: Build a search interface using Gradio for user queries on Keyword Based.
# 5. Testing and Evaluation: Test the functionality and performance of the search tool.
# 6. Deployment: Deploy the search tool for public access on a Hugging Face.

# %% [markdown]
# ## Data Information

# %%
import pandas as pd
data = pd.read_csv('AnalyticsVidhya.csv')

# %%
data.head(5)
# Out:
#    S.No                                        CourseTitle         Level  \
# 0     1  GenAI Applied to Quantitative Finance: For Con...  Intermediate
# 1     2  Navigating LLM Tradeoffs: Techniques for Speed...      Beginner
# 2     3  Creating Problem-Solving Agents using GenAI fo...      Beginner
# 3     4  Improving Real World RAG Systems: Key Challeng...      Beginner
# 4     5  Framework to Choose the Right LLM for your Bus...           NaN
#
#    Time(Hours)        Category  NumberOfLessons  \
# 0          1.0  Generative AI                 5
# 1          1.0  Generative AI                 6
# 2          1.0  Generative AI                 6
# 3          1.0  Generative AI                12
# 4          1.0  Generative AI                 6
#
#                                          Description  \
# 0  This course explores the application of Genera...
# 1  This course provides a concise guide to optimi...
# 2  This introductory course provides a concise ov...
# 3  This course explores the key challenges in bui...
# 4  This course will guide you through the process...
#
#                                           Curriculum Price
# 0  Introduction,Overview,Problem Definition: Comm...  Free
# 1  Introduction, Resources, Technique to Increase...  Free
# 2  Introduction, Overview- Count the Number of Ag...  Free
# 3  Introduction to RAG Systems, Resources, RAG Sy...  Free
# 4  Introduction, It’s an LLM World!, Understand Y...  Free

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   S.No             61 non-null     int64
#  1   CourseTitle      61 non-null     object
#  2   Level            58 non-null     object
#  3   Time(Hours)      59 non-null     float64
#  4   Category         61 non-null     object
#  5   NumberOfLessons  61 non-null     int64
#  6   Description      61 non-null     object
#  7   Curriculum       61 non-null     object
#  8   Price            61 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 4.4+ KB

# %% [markdown]
# ## Data Cleaning And Preprocessing

# %%
### Handling Missing Value

# %%
# Check for missing values in each column
missingvalues = data.isnull().sum()

# %%
print(missingvalues)
# Out:
# S.No               0
# CourseTitle        0
# Level              3
# Time(Hours)        2
# Category           0
# NumberOfLessons    0
# Description        0
# Curriculum         0
# Price              0
# dtype: int64

# %%
# Display rows with missing values
missingrows = data[data.isnull().any(axis=1)]
missingrows
# Out:
#     S.No                                        CourseTitle Level  \
# 4      5  Framework to Choose the Right LLM for your Bus...   NaN
# 24    25               Certified AI & ML BlackBelt+ Program   NaN
# 26    27                               AI Ethics by Fractal   NaN
#
#     Time(Hours)        Category  NumberOfLessons  \
# 4           1.0  Generative AI                 6
# 24          NaN    Data Science               33
# 26          NaN       AI Ethics                5
#
#                                           Description  \
# 4   This course will guide you through the process...
# 24  This comprehensive certified program combines ...
# 26  AI has a huge influence on our lives. From typ...
#
#                                            Curriculum  Price
# 4   Introduction, It’s an LLM World!, Understand Y...   Free
# 24  Introduction to Data Science and Machine Learn...  80000
# 26  Introduction and need for Ethical AI FREE PREV...    999

# %%
# Drop rows where 'Time(Hours)' or 'Level' 
data.dropna(subset=['Level', 'Time(Hours)'], inplace=True)

# %%
data
# Out:
#     S.No                                        CourseTitle         Level  \
# 0      1  GenAI Applied to Quantitative Finance: For Con...  Intermediate
# 1      2  Navigating LLM Tradeoffs: Techniques for Speed...      Beginner
# 2      3  Creating Problem-Solving Agents using GenAI fo...      Beginner
# 3      4  Improving Real World RAG Systems: Key Challeng...      Beginner
# 5      6  Building Smarter LLMs with Mamba and State Spa...      Advanced
# 6      7        Generative AI - A Way of Life - Free Course      Beginner
# 7      8  Building LLM Applications using Prompt Enginee...      Beginner
# 8      9  Building Your First Computer Vision Model - Fr...      Beginner
# 9     10   Bagging and Boosting ML Algorithms - Free Course  Intermediate
# 10    11  MidJourney: From Inspiration to Implementation...  Intermediate
# 11    12      Understanding Linear Regression - Free Course      Beginner
# 12    13       The Working of Neural Networks - Free Course      Beginner
# 13    14        The A to Z of Unsupervised ML - Free Course  Intermediate
# 14    15  Building Your first RAG System using LlamaInde...  Intermediate
# 15    16  Data Preprocessing on a Real-World Problem Sta...      Beginner
# 16    17               Exploring Stability.AI - Free Course      Beginner
# 17    18  Building a Text Classification Model with Natu...  Intermediate
# 18    19         Getting Started with Large Language Models      Beginner
# 19    20                      Introduction to Generative AI      Beginner
# 20    21  Nano Course: Dreambooth-Stable Diffusion for C...      Advanced
# 21    22  A Comprehensive Learning Path for Deep Learnin...      Beginner
# 22    23  A Comprehensive Learning Path to Become a Data...      Beginner
# 23    24  Nano Course: Building Large Language Models fo...  Intermediate
# 25    26                   Machine Learning Summer Training      Beginner
# 27    28  A Comprehensive Learning Path to Become a Data...      Beginner
# 28    29             Writing Powerful Data Science Articles  Intermediate
# 29    30  Machine Learning Certification Course for Begi...      Beginner
# 30    31  Data Science Career Conclave - Transition to D...      Beginner
# 31    32  Top Data Science Projects for Analysts and Dat...      Advanced
# 32    33  Getting Started with Git and GitHub for Data S...  Intermediate
# 33    34                   Machine Learning Starter Program      Beginner
# 34    35                Data Science Hacks, Tips and Tricks      Beginner
# 35    36                 Introduction to Business Analytics      Beginner
# 36    37          Introduction to PyTorch for Deep Learning      Beginner
# 37    38        Introduction to Natural Language Processing      Beginner
# 38    39                Getting started with Decision Trees  Intermediate
# 39    40                             Introduction to Python      Beginner
# 40    41    Loan Prediction Practice Problem (Using Python)  Intermediate
# 41    42                  Big Mart Sales Prediction Using R  Intermediate
# 42    43                         Twitter Sentiment Analysis  Intermediate
# 43    44                 Pandas for Data Analysis in Python      Beginner
# 44    45       Support Vector Machine (SVM) in Python and R  Intermediate
# 45    46     Evaluation Metrics for Machine Learning Models      Beginner
# 46    47                Fundamentals of Regression Analysis  Intermediate
# 47    48  Getting Started with scikit-learn (sklearn) fo...  Intermediate
# 48    49   Convolutional Neural Networks (CNN) from Scratch      Advanced
# 49    50      Dimensionality Reduction for Machine Learning      Advanced
# 50    51  K-Nearest Neighbors (KNN) Algorithm in Python ...  Intermediate
# 51    52  Ensemble Learning and Ensemble Learning Techni...  Intermediate
# 52    53  Linear Programming for Data Science Professionals      Advanced
# 53    54                           Naive Bayes from Scratch      Advanced
# 54    55                       Learn Swift for Data Science      Advanced
# 55    56          Introduction to Web Scraping using Python      Beginner
# 56    57                              Tableau for Beginners      Beginner
# 57    58               Getting Started with Neural Networks      Beginner
# 58    59                            Introduction to AI & ML      Beginner
# 59    60  Winning Data Science Hackathons - Learn from E...      Beginner
# 60    61  Hypothesis Testing for Data Science and Analytics  Intermediate
#
#     Time(Hours)            Category  NumberOfLessons  \
# 0          1.00      Generative AI                 5
# 1          1.00      Generative AI                 6
# 2          1.00      Generative AI                 6
# 3          1.00      Generative AI                12
# 5          2.00      Generative AI                14
# 6          6.00      Generative AI                31
# 7          2.10      Generative AI                17
# 8          0.50      Deep Learning                 7
# 9          1.00    Machine Learning               16
# 10         0.50      Generative AI                 5
# 11         1.00    Machine Learning               10
# 12         1.50       Deep Learning               11
# 13         1.00    Machine Learning               13
# 14         1.10      Generative AI                12
# 15         1.00        Basic Python               13
# 16         1.00      Generative AI                 7
# 17         1.10                 NLP               16
# 18         1.20      Generative AI                18
# 19         1.00      Generative AI                 9
# 20         1.00      Generative AI                13
# 21       120.00       Deep Learning               72
# 22         2.00        Data Science              389
# 23         0.50      Generative AI                10
# 25        40.00    Machine Learning              263
# 27       120.00       Data Engineer              205
# 28         1.00        Data Science                6
# 29         6.00    Machine Learning              261
# 30         1.00        Data Science                6
# 31         6.00            Projects               36
# 32         4.00   Tools & Framework               20
# 33         6.00    Machine Learning                3
# 34         7.00        Data Science               37
# 35         1.00  Business Analytics               32
# 36         1.00   Tools & Framework               28
# 37         5.00                 NLP               21
# 38         2.00    Machine Learning               21
# 39         1.00   Tools & Framework               69
# 40         2.00            Projects               16
# 41         2.00            Projects               19
# 42         3.00       Projects, NLP               18
# 43         7.00   Tools & Framework               27
# 44         2.00    Machine Learning               13
# 45         2.00    Machine Learning               25
# 46         3.00    Machine Learning               24
# 47         4.00   Tools & Framework               27
# 48         6.00       Deep Learning               17
# 49         4.00    Machine Learning               23
# 50         2.00    Machine Learning               10
# 51         4.00    Machine Learning               37
# 52         3.00    Machine Learning               20
# 53         0.50    Machine Learning               19
# 54         2.00   Tools & Framework               21
# 55         1.00   Tools & Framework               13
# 56         0.25  Business Analytics               17
# 57         1.20       Deep Learning               46
# 58         2.00        Data Science               17
# 59         1.00        Data Science                7
# 60         4.00          Statistics               19
#
#                                           Description  \
# 0   This course explores the application of Genera...
# 1   This course provides a concise guide to optimi...
# 2   This introductory course provides a concise ov...
# 3   This course explores the key challenges in bui...
# 5   Unlock the Power of State Space Models (SSM) l...
# 6   This course is a transformative journey tailor...
# 7   This free course offers a comprehensive guide ...
# 8   This course will help you gain a deep understa...
# 9   This course will provide you with a hands-on u...
# 10  This course will provide you with a practical ...
# 11  This free course will help you understand the ...
# 12  This free course will help you understand the ...
# 13  Unsupervised machine learning helps uncover hi...
# 14  This course will guide you through building yo...
# 15  This course will help you get a practical unde...
# 16  This course will give you a practical understa...
# 17  Gain practical insights into Natural Language ...
# 18  This course will help you gain a comprehensive...
# 19  This course will provide you with a comprehens...
# 20  Theory to Practice: Dive into Stable Diffusion...
# 21  The most common question we get from beginners...
# 22  Want to become a data scientist this year, but...
# 23  Learn how to train Large Language Models for C...
# 25  In this free Machine Learning Summer Training,...
# 27  Want to become a data engineer this year, but ...
# 28  Are you looking to write and publish your data...
# 29  In this free machine learning certification co...
# 30  Here’s the perfect course to help you get all ...
# 31  Kick-start your career in data science with ou...
# 32  Upskill your data science acumen with Analytic...
# 33  Step-by-step online program to learn the basic...
# 34  Learn key data science hacks, tips and tricks ...
# 35  Business analytics is thriving – and so is its...
# 36  PyTorch is a popular and leading deep learning...
# 37  Natural Language Processing (NLP) is the art o...
# 38  Decision Tree algorithm is one of the most pow...
# 39  Power up your career with the best and most po...
# 40  This course is aimed for people getting starte...
# 41  This course is aimed for people getting starte...
# 42  What is sentiment analysis? Why is sentiment a...
# 43  What is Pandas? How can you perform data analy...
# 44  What is a Support Vector Machine (SVM) in mach...
# 45  What are evaluation metrics in machine learnin...
# 46  What is regression analysis? What are the diff...
# 47  Scikit-learn (Sklearn) - the powerful Python l...
# 48  Convolutional neural networks, or CNNs, have t...
# 49  Dimensionality reduction is a key concept in m...
# 50  A practical hands-on tutorial on the K-Nearest...
# 51  Ensemble learning is a powerful machine learni...
# 52  The Linear Programming for Data Science Profes...
# 53  Naive Bayes is a popular and widely used machi...
# 54  Swift for Data Science introduces you to the w...
# 55  What is web scraping? Why is web scraping a mu...
# 56  Tableau is the tool of choice for business int...
# 57  Kick start your journey in deep learning with ...
# 58  Artificial Intelligence (AI) and Machine Learn...
# 59  Competing in a data science hackathon is all a...
# 60  Hypothesis testing is one of the most fascinat...
#
#                                            Curriculum Price
# 0   Introduction,Overview,Problem Definition: Comm...  Free
# 1   Introduction, Resources, Technique to Increase...  Free
# 2   Introduction, Overview- Count the Number of Ag...  Free
# 3   Introduction to RAG Systems, Resources, RAG Sy...  Free
# 5   Course Overview, An Alternative to Transformer...  Free
# 6   Introduction to Generative AI, Text Generation...  Free
# 7   How to build different LLM Applications?, Gett...  Free
# 8   Pixel Perfect - Decoding Images, Understanding...  Free
# 9                                   Bagging, Boosting  Free
# 10  MidJourney - Storm _ Story, MidJourney - Inspi...  Free
# 11  Introduction to the Problem Statement, Resourc...  Free
# 12  How are Neural Networks trained - Forward Prop...  Free
# 13  Resources to be used in this course, Setting t...  Free
# 14  Introduction to RAG systems, Getting Started w...  Free
# 15  Resources to be used in this course, Introduct...  Free
# 16  Introduction to Stability, How to use Stabilit...  Free
# 17  Introduction to NLP, Building a basic classifi...  Free
# 18  Introduction, The Evolution of NLP, What are L...  Free
# 19  What is Generative AI, How does Gen AI work, Q...  Free
# 20  The Current Landscape of Generative AI, Why St...  Free
# 21                        Quizzes, Exercises and More  Free
# 22  Overview of the Learning Path, Data Science To...  Free
# 23  Introduction, Agenda, BigCode Community, Train...  Free
# 25  Overview of the Course, Introduction to Data S...  Free
# 27  Overview of Learning Path, Learn Programming, ...  Free
# 28  Welcome to the Data Science Writing Crash Cour...  Free
# 29  Overview of the Course, Introduction to Data S...  Free
# 30  Introduction to the Career Conclave, Different...  Free
# 31  Welcome to the course!, Machine Learning Proje...  Free
# 32  Getting Familiar with Git and Github, Understa...  Free
# 33                  Introduction to Machine Learning…  Free
# 34  Introduction to Data Science Hacks, Tips and T...  Free
# 35  What is Business Analytics?, Spectrum of Busin...  Free
# 36  What is PyTorch?, Neural Networks, Implementin...  Free
# 37  Introduction to Natural Language Processing, L...  Free
# 38  Introduction to Decision Tree, Purity in Decis...  Free
# 39  Overview of the Course, Introduction to Python...  Free
# 40  Introduction to the Course, Table of Contents,...  Free
# 41  Overview of the Course, Table of contents, Pro...  Free
# 42  Overview of the Course, Understand the Problem...  Free
# 43  Getting Started with Pandas, Dataset Descripti...  Free
# 44  Introduction to Support Vector Machines, How d...  Free
# 45  Introduction, Evaluation Metrics: Classificati...  Free
# 46  Welcome to the course!, Introduction to Regres...  Free
# 47  Welcome to the course!, scikit-learn in Python...  Free
# 48  Introduction to Neural Networks, Introduction ...  Free
# 49  Introduction to the Course, Introduction to Di...  Free
# 50  Introduction, K-NEAREST NEIGHBOUR, Steps to Bu...  Free
# 51  Introduction, Basic Ensemble Learning Techniqu...  Free
# 52  Introduction to Linear Programming, Introducti...  Free
# 53  Probability, The Naive Bayes Algorithm, What N...  Free
# 54  Introduction, Swift Basics for Data Analysis, ...  Free
# 55  Introduction to Web Scraping, Web Scraping: Pr...  Free
# 56  Introduction, Concept of Visualization, Unders...  Free
# 57  Introduction to Deep Learning, Getting ready f...  Free
# 58  Introduction to AI & ML, Common Terminologies,...  Free
# 59  Introduction to Winning Data Science Hackathon...  Free
# 60  Introduction to the course, Fundamentals of Hy...  Free

# %% [markdown]
# ### Preprocessing the Data for Embedding
#
# We will need to clean the text data in the CourseTitle and  Description columns before generating embeddings.
# 1. Lowercasing all text.
# 2. Removing special characters.

# %%
import re
def cleantext(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    return text
data['CourseTitle'] = data['CourseTitle'].apply(cleantext)
data['Description'] = data['Description'].apply(cleantext)

# %%
data.head(3)
# Out:
#    S.No                                        CourseTitle         Level  \
# 0     1  genai applied to quantitative finance for cont...  Intermediate
# 1     2  navigating llm tradeoffs techniques for speed ...      Beginner
# 2     3  creating problemsolving agents using genai for...      Beginner
#
#    Time(Hours)        Category  NumberOfLessons  \
# 0          1.0  Generative AI                 5
# 1          1.0  Generative AI                 6
# 2          1.0  Generative AI                 6
#
#                                          Description  \
# 0  this course explores the application of genera...
# 1  this course provides a concise guide to optimi...
# 2  this introductory course provides a concise ov...
#
#                                           Curriculum Price
# 0  Introduction,Overview,Problem Definition: Comm...  Free
# 1  Introduction, Resources, Technique to Increase...  Free
# 2  Introduction, Overview- Count the Number of Ag...  Free

# %% [markdown]
# ## Embedding Model

# %%
# Install Library
# !pip install transformers sentence-transformers
# Out:
# Requirement already satisfied: transformers in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (4.45.2)
# Requirement already satisfied: sentence-transformers in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (3.2.1)
# Requirement already satisfied: filelock in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from transformers) (0.26.1)
# Requirement already satisfied: numpy>=1.17 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from transformers) (0.20.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from sentence-transformers) (2.3.0)
# Requirement already satisfied: scikit-learn in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from sentence-transformers) (1.3.0)
# Requirement already satisfied: scipy in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from sentence-transformers) (1.11.1)
# Requirement already satisfied: Pillow in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: sympy in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: networkx in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/chanchalalam/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)

# %%
#Import Pre-trained Model
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# /Users/chanchalalam/anaconda3/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
# Generate embeddings for the course descriptions
data['DescriptionEmbeddings'] = data['Description'].apply(lambda desc: model.encode(desc))
# Generate embeddings for course titles 
data['TitleEmbeddings'] = data['CourseTitle'].apply(lambda x: model.encode(x))

# %%
data.to_csv('courseswithembeddings.csv', index=False)

# %% [markdown]
#  ## Search Tool Development

# %%
#Implement the Search Functionality
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Set display options
pd.set_option('display.max_colwidth', 100) 
pd.set_option('display.width', 1000) 

def search_courses(query, data, model):
    # Generate embedding for the user query
    queryembedding = model.encode(query)
    
    # Compute cosine similarity between query and course descriptions
    similarities = cosine_similarity([queryembedding], list(data['DescriptionEmbeddings']))[0]
    
    # Top 5 results
    top5 = 5  
    topindices = similarities.argsort()[-top5:][::-1]
    
    # Retrieve the top results
    results = data.iloc[topindices]
    return results[['CourseTitle', 'Level', 'Category']]

# %% [markdown]
# ### Keyword-Based Search for Free Courses

# %%
#Create the User Interface with Gradio
import gradio as gr
data['CourseTitle'] = data['CourseTitle'].str.title()
def searchinterface(query):
    results = search_courses(query, data, model)
    return results.to_string(index=False)

# Create Gradio interface
interface = gr.Interface(
    fn=searchinterface, 
    inputs="text", 
    outputs="text", 
    title="Smart Engine for Free Courses",
    description="Enter Topic to find relevant free courses."
)

# Launch the interface
interface.launch()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# * Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Semantic Search for Free Courses

# %%
import gradio as gr
import pandas as pd
import torch
from sentence_transformers import SentenceTransformer, util

courseEmbeddings = model.encode(data['CourseTitle'].tolist(), convert_to_tensor=True)

def searchCourses(query):
    # Encode the user query to get its embedding
    queryEmbedding = model.encode(query, convert_to_tensor=True)
    
    # Compute cosine similarities between the query and course embeddings
    cosineScores = util.pytorch_cos_sim(queryEmbedding, courseEmbeddings)[0]
    topResults = torch.topk(cosineScores, k=3)

    results = []
    for score, idx in zip(topResults[0], topResults[1]):
        idx = idx.item()  
        results.append(f"{data.iloc[idx]['CourseTitle']} (Score: {score.item():.4f})")
    return "\n".join(results)

def searchInterface(query):
    if query.strip() == "":
        return "Please enter a search term."
    
    results = searchCourses(query)
    return results if results else "No results found."

interface = gr.Interface(
    fn=searchInterface, 
    inputs=gr.Textbox(label="Search Topic", placeholder="Enter a topic..."), 
    outputs=gr.Textbox(label="Results"),
    title="Semantic Search for Free Courses",
    description="Enter a topic to find relevant free courses using semantic search."
)

interface.launch()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# * Running on local URL:  http://127.0.0.1:7866
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Semantic Search with Re-Ranking for Free Courses

# %%
import gradio as gr
import pandas as pd
import torch
from sentence_transformers import SentenceTransformer, util

def searchCourses(query):
    queryEmbedding = model.encode(query, convert_to_tensor=True)
    cosineScores = util.pytorch_cos_sim(queryEmbedding, courseEmbeddings)[0]
    topResults = torch.topk(cosineScores, k=5)
    initialResults = [(score.item(), idx.item()) for score, idx in zip(topResults[0], topResults[1])]
    reRankedResults = reRankResults(initialResults, queryEmbedding)
    return reRankedResults

def reRankResults(initialResults, queryEmbedding):
    scores = []
    for score, idx in initialResults:
        courseTitle = data.iloc[idx]['CourseTitle']
        courseEmbedding = model.encode(courseTitle, convert_to_tensor=True)
        reRankedScore = util.pytorch_cos_sim(queryEmbedding, courseEmbedding).item()
        scores.append((reRankedScore, courseTitle))
    scores.sort(key=lambda x: x[0], reverse=True)
    results = [f"{title} (Score: {score:.4f})" for score, title in scores]
    return "\n".join(results)

def searchInterface(query):
    if query.strip() == "":
        return "Please enter a search term."
    
    results = searchCourses(query)
    return results if results else "No results found."

# Create Gradio interface
interface = gr.Interface(
    fn=searchInterface, 
    inputs=gr.Textbox(label="Search Topic", placeholder="Enter a topic..."), 
    outputs=gr.Textbox(label="Results"),
    title="Semantic Search with Re-Ranking for Free Courses",
    description="Enter a topic to find relevant free courses using semantic search and re-ranking."
)

# Launch the interface
interface.launch()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# * Running on local URL:  http://127.0.0.1:7869
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7869/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import pandas as pd
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer
import gradio as gr


df = pd.read_csv('AnalyticsVidhya.csv')

# Load the pre-trained model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Step 1: Combine the relevant columns to create a single text representation
df['CombinedText'] = df.apply(
    lambda row: (
        f"Title: {str(row['CourseTitle'])}. "
        f"Level: {str(row['Level']) if pd.notnull(row['Level']) else 'Not specified'}. "
        f"Duration: {str(row['Time(Hours)']) if pd.notnull(row['Time(Hours)']) else 'Unknown'} hours. "
        f"Category: {str(row['Category']) if pd.notnull(row['Category']) else 'Not specified'}. "
        f"Description: {str(row['Description']) if pd.notnull(row['Description']) else 'No description available'}"
    ), axis=1)

# Step 2: Generate embeddings for all courses
embeddings = model.encode(df['CombinedText'].tolist(), show_progress_bar=True)

# Step 3: Create FAISS index
embedding_dim = embeddings.shape[1]
index = faiss.IndexFlatL2(embedding_dim)

# Add the embeddings to the index
index.add(np.array(embeddings))

# Step 4: Search function to query courses
def search_courses(query, top_k=5):
    # Generate embedding for the query
    query_embedding = model.encode([query])[0]

    # Perform the search in FAISS
    distances, indices = index.search(np.array([query_embedding]), top_k)

    # Retrieve the corresponding course information
    results = []
    for idx in indices[0]:
        course = {
            'CourseTitle': df.iloc[idx]['CourseTitle'],
            'Description': df.iloc[idx]['Description'],
            'Level': df.iloc[idx]['Level'],
            'Category': df.iloc[idx]['Category'],
            'NumberOfLessons': df.iloc[idx]['NumberOfLessons']
        }
        results.append(course)
    
    return results

# Step 5: Define Gradio interface function
def gradio_search(query, top_k):
    results = search_courses(query, top_k)
    display_results = [
        f"Title: {res['CourseTitle']}\n"
        f"Description: {res['Description']}\n"
        f"Category: {res['Category']}\n"
        f"Level: {res['Level']}"
        for res in results
    ]
    return "\n\n".join(display_results)

# Step 6: Create Gradio interface
interface = gr.Interface(
    fn=gradio_search,
    inputs=[
        gr.Textbox(label="Search in our courses"),
        gr.Slider(minimum=1, maximum=10, step=1, value=5, label="Number of Results")
    ],
    outputs="text",
    title="Smart Course Search",
    description="Analytics Vidhya Free Courses",
    flagging_mode=None  # Disable flagging button
)

# Step 7: Launch the Gradio interface
interface.launch()
# Out:
# /Users/chanchalalam/anaconda3/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# * Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
